# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Age"].plot(kind="kde")
plt.show()

# %%
df["Age"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df[df["Age"]>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df[df["Age"]>70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df["Age"].isnull().sum()/len(df["Age"])*100
# Out:
# 19.865319865319865

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df["Fare"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["Fare"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df["Fare"].skew()
# Out:
# 4.787316519674893

# %%
df["Fare"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df[df["Fare"]>200]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
df[df["Fare"]>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df["Fare"].isnull().sum()
# Out:
# 0

# %%
[faeture for faeture in df.columns if df[faeture].dtypes=="object" ]
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df["Survived"].value_counts().plot(kind="pie",autopct="%.01f%%")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df["Survived"].isnull().sum()
# Out:
# 0

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
df["Sex"].isnull().sum()
# Out:
# 0

# %%
df["SibSp"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.heatmap(pd.crosstab(df["Survived"],df["Pclass"],normalize="columns")*100)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df["Survived"],df["Sex"],normalize="columns")*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df["Survived"],df["Pclass"],normalize="columns")
# Out:
# Pclass          1         2         3
# Survived
# 0         0.37037  0.527174  0.757637
# 1         0.62963  0.472826  0.242363

# %%
pd.crosstab(df["Survived"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df["Sex"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df["Pclass"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
df[df["Survived"]==1]["Age"].plot(kind="kde",label="Survived")
df[df["Survived"]==0]["Age"].plot(kind="kde",label="Not_Survived")
plt.legend()
plt.show()

# %%
df[df["Pclass"]==1]["Age"].mean()
# Out:
# 38.233440860215055

# %%
df["Fare"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df["SibSp"].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df[df["SibSp"]==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df["Ticket"]=="CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df["Name"].str.contains("Sage")]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df_1=pd.read_csv("test.csv")
df_1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df=pd.concat([df,df_1])

# %%
df[df["Ticket"]=="CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
# ...

# %%
df["Ticket"].value_counts()
# Out:
# CA. 2343        15
# PC 17608        12
# 347077          10
# CA 2144         10
# S.O.C. 14879     9
#                 ..
# 113792           1
# 36209            1
# 323592           1
# 315089           1
# 218629           1
# Name: Ticket, Length: 929, dtype: int64

# %%
df[df["Ticket"]=="CA 2144"]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
df["individual_fare"]=df["Fare"]/(df["SibSp"]+df["Parch"]+1)

# %%
df[df["Fare"]==512.3292]
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259       1.0       1
# 679          680       1.0       1
# 737          738       1.0       1
# 343         1235       NaN       1
# 343         1235       NaN       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked  individual_fare
# 258      0  PC 17755  512.3292          NaN        C         512.3292
# 679      1  PC 17755  512.3292  B51 B53 B55        C         256.1646
# 737      0  PC 17755  512.3292         B101        C         512.3292
# ...

# %%
df["Family_size"]=df["SibSp"]+df["Parch"]+1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def transform_family_size(num):
    if num==1:
        return "Alone"
    elif num>1 and num <5:
        return "Small"
    else:
        return "Large"

# %%
df["family_size_assumption"]=df["Family_size"].apply(transform_family_size)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df["Survived"],df["family_size_assumption"],normalize="columns")*100
# Out:
# family_size_assumption      Alone      Large      Small
# Survived
# 0.0                     69.646182  83.870968  42.123288
# 1.0                     30.353818  16.129032  57.876712

# %%
df["sername"]=df["Name"].str.split(",").str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["title_family"]=df["Name"].str.split(",").str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
temp_df=df[df["title_family"].isin(["Mr.","Mrs.","Miss.","Master.","oother"])]

# %%
pd.crosstab(temp_df["Survived"],temp_df["title_family"],normalize="columns")*100
# Out:
# title_family  Master.     Miss.        Mr.  Mrs.
# Survived
# 0.0              42.5  30.21978  84.332689  20.8
# 1.0              57.5  69.78022  15.667311  79.2

# %%
pd.crosstab(df["Survived"],df["title"])
# Out:
# title     Capt.  Col.  Don.  Dr.  Jonkheer.  Lady.  Major.  Master.  Miss.  \
# Survived
# 0.0           1     1     1    4          1      0       1       17     55
# 1.0           0     1     0    3          0      1       1       23    127
#
# title     Mlle.  Mme.  Mr.  Mrs.  Ms.  Rev.  Sir.  the
# Survived
# 0.0           0     0  436    26    0     6     0    0
# 1.0           2     1   81    99    1     0     1    1

# %%
df["title_family"]=df["title_family"].str.replace("Rev.","other")
df["title_family"]=df["title_family"].str.replace("Dr.","other")
df["title_family"]=df["title_family"].str.replace("Major.","other")
df["title_family"]=df["title_family"].str.replace("Don.","other")
df["title_family"]=df["title_family"].str.replace("Capt.","other")
df["title_family"]=df["title_family"].str.replace("the.","other")
df["title_family"]=df["title_family"].str.replace("jonkheer.","other")
# Out:
# C:\Users\Yaksha\AppData\Local\Temp\ipykernel_488\1369978882.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["title_family"]=df["title_family"].str.replace("Rev.","other")
# C:\Users\Yaksha\AppData\Local\Temp\ipykernel_488\1369978882.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["title_family"]=df["title_family"].str.replace("Dr.","other")
# C:\Users\Yaksha\AppData\Local\Temp\ipykernel_488\1369978882.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["title_family"]=df["title_family"].str.replace("Major.","other")
# C:\Users\Yaksha\AppData\Local\Temp\ipykernel_488\1369978882.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["title_family"]=df["title_family"].str.replace("Don.","other")
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Cabin"].isnull().sum()/len(df["Cabin"])*100
# Out:
# 77.64910248986682

# %%
df["Cabin"].fillna("M",inplace=True)

# %%
df["Cabin"].value_counts()
# Out:
# M                  1341
# C23 C25 C27           8
# B57 B59 B63 B66       8
# F4                    6
# C78                   6
#                    ...
# C128                  1
# C82                   1
# E10                   1
# D49                   1
# B38                   1
# Name: Cabin, Length: 187, dtype: int64

# %%
df["Deck"]=df["Cabin"].str[0]

# %%
df["Deck"].value_counts()
# Out:
# M    1341
# C     129
# B      83
# D      59
# E      50
# A      29
# F      29
# G       6
# T       1
# Name: Deck, dtype: int64

# %%
pd.crosstab(df["Deck"],df["Pclass"])
# Out:
# Pclass    1    2    3
# Deck
# A        29    0    0
# B        83    0    0
# C       129    0    0
# D        51    8    0
# E        43    4    3
# F         0   18   11
# G         0    0    6
# M        94  340  907
# T         1    0    0

# %%
pd.crosstab(df["Deck"],df["Survived"],normalize="index").plot(kind="bar",stacked=True)
# Out:
# <AxesSubplot:xlabel='Deck'>
